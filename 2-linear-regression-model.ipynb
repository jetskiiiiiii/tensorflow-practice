# %%
import __future__ as fu
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import keras as ks

# %%
import sklearn.datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
cali_dataset = sklearn.datasets.fetch_california_housing()

# %%
feature_columns = cali_dataset.feature_names

# %%
target_column = cali_dataset.target

# %%
cali_dataset = pd.DataFrame(cali_dataset.data, columns=feature_columns).astype(np.float32)

# %%
cali_dataset['MEDV'] = target_column.astype(np.float32)

# %%
cali_dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup   Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556  37.880001
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842  37.860001
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260  37.849998
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945  37.849998
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467  37.849998
#
#     Longitude   MEDV
# 0 -122.230003  4.526
# 1 -122.220001  3.585
# 2 -122.239998  3.521
# 3 -122.250000  3.413
# 4 -122.250000  3.422

# %%
sns.pairplot(cali_dataset, diag_kind='kde')

# %%
correlation_data = cali_dataset.corr()

# %%
correlation_data.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_749d4_row0_col0, #T_749d4_row1_col1, #T_749d4_row2_col2, #T_749d4_row3_col3, #T_749d4_row4_col4, #T_749d4_row5_col5, #T_749d4_row6_col6, #T_749d4_row7_col7, #T_749d4_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_749d4_row0_col1, #T_749d4_row1_col0 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_749d4_row0_col2, #T_749d4_row2_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_749d4_row0_col3, #T_749d4_row3_col0, #T_749d4_row3_col4, #T_749d4_row4_col3 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_749d4_row0_col4, #T_749d4_row4_col0, #T_749d4_row5_col6, #T_749d4_row5_col7, #T_749d4_row6_col5, #T_749d4_row7_col5 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_749d4_row0_col5, #T_749d4_row5_col0 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_749d4_row0_col6, #T_749d4_row1_col3, #T_749d4_row3_col1, #T_749d4_row6_col0 {
#   background-color: #ccd9ed;
# ...

# %%
stats = cali_dataset.describe()

# %%
cali_stats = stats.transpose()
cali_stats
# Out:
#               count         mean          std         min         25%  \
# MedInc      20640.0     3.870671     1.899822    0.499900    2.563400
# HouseAge    20640.0    28.639486    12.585557    1.000000   18.000000
# AveRooms    20640.0     5.429000     2.474173    0.846154    4.440716
# AveBedrms   20640.0     1.096675     0.473911    0.333333    1.006079
# Population  20640.0  1425.476685  1132.462158    3.000000  787.000000
# AveOccup    20640.0     3.070655    10.386049    0.692308    2.429741
# Latitude    20640.0    35.631863     2.135952   32.540001   33.930000
# Longitude   20640.0  -119.569710     2.003532 -124.349998 -121.800003
# MEDV        20640.0     2.068558     1.153956    0.149990    1.196000
#
#                     50%          75%           max
# MedInc         3.534800     4.743250     15.000100
# HouseAge      29.000000    37.000000     52.000000
# AveRooms       5.229129     6.052381    141.909088
# AveBedrms      1.048780     1.099526     34.066666
# ...
